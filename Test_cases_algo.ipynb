# %%
#==============SIMPUNGWE=======W==========Jonathan===========#
#pip install --upgrade --force-reinstall tensorflow-gpu==1.15.0

# %%
pip install --upgrade --force-reinstall tensorflow-gpu==1.15.0
# Out:
# ...
#      |████████████████████████████████| 411.5MB 39kB/s
# ...
#      |████████████████████████████████| 71kB 9.0MB/s
# ...
#      |████████████████████████████████| 1.3MB 46.5MB/s
# ...
#      |████████████████████████████████| 51kB 6.6MB/s
# ...
#      |████████████████████████████████| 61kB 7.2MB/s
# ...
#      |████████████████████████████████| 51kB 6.9MB/s
# ...
#      |████████████████████████████████| 3.0MB 44.6MB/s
# ...
#      |████████████████████████████████| 512kB 45.8MB/s
# ...
#      |████████████████████████████████| 14.5MB 319kB/s
# ...
#      |████████████████████████████████| 112kB 51.9MB/s
# ...
#      |████████████████████████████████| 3.8MB 43.2MB/s
# ...
#      |████████████████████████████████| 798kB 33.4MB/s
# ...
#      |████████████████████████████████| 2.9MB 37.2MB/s
# ...
#      |████████████████████████████████| 307kB 39.6MB/s
# ...
#      |████████████████████████████████| 92kB 8.1MB/s
# ...

# %%
#=======Install the dependecies=====#
# !pip install imageai --upgrade
# Out:
# ...
#      |████████████████████████████████| 184kB 8.6MB/s
# ...

# %%
pip install keras

# %%
import cv2
cv2.__version__
# Out:
# '4.1.2'

# %%
pip install keras

# %%
pip uninstall protobuf python3-protobuf
# Out:
# Uninstalling protobuf-3.12.2:
#   Would remove:
#     /usr/local/lib/python3.6/dist-packages/google/protobuf/*
#     /usr/local/lib/python3.6/dist-packages/protobuf-3.12.2-py3.6-nspkg.pth
#     /usr/local/lib/python3.6/dist-packages/protobuf-3.12.2.dist-info/*
# Proceed (y/n)? y
#   Successfully uninstalled protobuf-3.12.2
# WARNING: Skipping python3-protobuf as it is not installed.

# %%
pip install --upgrade pip
# Out:
# ...
#      |████████████████████████████████| 1.5MB 8.1MB/s
# ...
#   Found existing installation: pip 19.3.1
#     Uninstalling pip-19.3.1:
#       Successfully uninstalled pip-19.3.1
# ...

# %%
pip install --upgrade protobuf
# Out:
# ...
#   Using cached protobuf-3.12.2-cp36-cp36m-manylinux1_x86_64.whl (1.3 MB)
# ...
# ERROR: tensorflow 2.2.0 has requirement gast==0.3.3, but you'll have gast 0.2.2 which is incompatible.
# ERROR: tensorflow 2.2.0 has requirement tensorboard<2.3.0,>=2.2.0, but you'll have tensorboard 1.15.0 which is incompatible.
# ERROR: tensorflow 2.2.0 has requirement tensorflow-estimator<2.3.0,>=2.2.0, but you'll have tensorflow-estimator 1.15.1 which is incompatible.
# ...

# %%
#=========Mounting your google drive==to==google==colab=====#
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# !pip install imageai-2.0.2-py3-none-any.whl
# Out:
# WARNING: Requirement 'imageai-2.0.2-py3-none-any.whl' looks like a filename, but the file does not exist
# Processing ./imageai-2.0.2-py3-none-any.whl
# ERROR: Could not install packages due to an EnvironmentError: [Errno 2] No such file or directory: '/content/imageai-2.0.2-py3-none-any.whl'

# %%
pip install imageai --upgrade
# Out:
# Requirement already up-to-date: imageai in /usr/local/lib/python3.6/dist-packages (2.1.5)
# ...

# %%
from imageai.Detection import ObjectDetection
import os
detector = ObjectDetection()
# Out:
# Using TensorFlow backend.

# %%
#======Setting the model path=====#

model_path = "/content/drive/My Drive/Object_detection_model/resnet50_coco_best_v2.0.1.h5" #resnet50_coco_best_v2.0.1.h5
model_path1 = "/content/drive/My Drive/Object_detection_model/yolo-tiny.h5"  #Yolo-tiny.h5
model_path2 = "/content/drive/My Drive/object_detection_model_1/resnet50_coco_best_v2.0.1.h5" #resnet50_coco_best_v2.0.1.h5
model_path3 = "/content/drive/My Drive/object_detection_model_1/yolo.h5"

#=========1st=input===image==#
input_path = "/content/drive/My Drive/Object_detection_model/CarTraffic.jpg"  
output_path = "/content/drive/My Drive/Object_detection_model/CarTraffic_OUT.jpg"

#=========2nd===image==basketBall========#
input_path2 = "/content/drive/My Drive/Object_detection_model/basketBall.jpg"
output_path2 = "/content/drive/My Drive/Object_detection_model/basketBall_OUT2.jpg"

#========3rd====image==basketBall_Rim========#

input_path3 = "/content/drive/My Drive/Object_detection_model/basketBall_Rim.jpg"
output_path3 = "/content/drive/My Drive/Object_detection_model/basketBall_Rim_OUTPUT.jpg"

#================4th==video=============#
input_path4 = "/content/drive/My Drive/video.mp4"
output_path4 = "/content/drive/My Drive/video_output.mp4"

# %%
#==============Basketball_RIM ==== detection scenario=============#

detector.setModelPath(model_path1) # this function allows us to specify the path (Yolo-tiny.h5)
detector.setModelTypeAsTinyYOLOv3()
detector.loadModel() # this fucntion allows us to load the model
detection = detector.detectObjectsFromImage(input_image=input_path3, output_image_path=output_path3)

#=========This loop gives us the percetage of the probability of the detected object======#
for eachItem in detection:
    print(eachItem["name"] , " : ", eachItem["percentage_probability"])

# %%
#==============Car detection scenario=============#

detector.setModelPath(model_path) # this function allows us to specify the path (resnet50_coco_best_v2.0.1.h5)
detector.setModelTypeAsRetinaNet() #Model type
detector.loadModel() # this fucntion allows us to load the model
detection = detector.detectObjectsFromImage(input_image=input_path, output_image_path=output_path)

#=========This loop gives us the percetage of the probability of the detected object======#
for eachItem in detection:
    print(eachItem["name"] , " : ", eachItem["percentage_probability"])
# Out:
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/imageai/Detection/__init__.py in detectObjectsFromImage(self, input_image, output_image_path, input_type, output_type, extract_detected_objects, minimum_percentage_probability, display_percentage_probability, display_object_name, thread_safe)
#     346                     else:
# --> 347                         _, _, detections = model.predict_on_batch(np.expand_dims(image, axis=0))
#     348
#
# /usr/local/lib/python3.6/dist-packages/keras/engine/training.py in predict_on_batch(self, x)
#    1579         self._make_predict_function()
# -> 1580         outputs = self.predict_function(ins)
#    1581         return unpack_singleton(outputs)
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/keras/backend.py in __call__(self, inputs)
# ...

# %%
#==============Basketball_detection scenario=============#

detector.setModelPath(model_path1) # this function allows us to specify the path (Yolo-tiny.h5)
detector.setModelTypeAsTinyYOLOv3() #Set model type
detector.loadModel() # this fucntion allows us to load the model
detection = detector.detectObjectsFromImage(input_image=input_path2, output_image_path=output_path2)

#=========This loop gives us the percetage of the probability of the detected object======#
for eachItem in detection:
    print(eachItem["name"] , " : ", eachItem["percentage_probability"])

# %%
#==============Video detection scenario=============#
from imageai.Detection import VideoObjectDetection
import os
import cv2

execution_path = os.getcwd()

#camera = cv2.VideoCapture(0)
detector.setModelTypeAsRetinaNet()
detector1 = VideoObjectDetection()
detector1.setModelTypeAsYOLOv3() #Model type
detector1.setModelPath(model_path3)  #we apply the yolo.h5 model
detector1.loadModel() #Load the model

print(detector1)

# %%
video_path = detector1.detectObjectsFromVideo(input_file_path=os.path.join(execution_path, input_path4),
                                output_file_path=os.path.join(execution_path, output_path4)
                                , frames_per_second=20, log_progress=True)
print(video_path)
# Out:
# Processing Frame :  1
# Processing Frame :  2
# Processing Frame :  3
# Processing Frame :  4
# Processing Frame :  5
# Processing Frame :  6
# Processing Frame :  7
# Processing Frame :  8
# Processing Frame :  9
# Processing Frame :  10
# Processing Frame :  11
# Processing Frame :  12
# Processing Frame :  13
# Processing Frame :  14
# Processing Frame :  15
# Processing Frame :  16
# Processing Frame :  17
# Processing Frame :  18
# Processing Frame :  19
# Processing Frame :  20
# Processing Frame :  21
# Processing Frame :  22
# Processing Frame :  23
# Processing Frame :  24
# Processing Frame :  25
# Processing Frame :  26
# Processing Frame :  27
# Processing Frame :  28
# Processing Frame :  29
# Processing Frame :  30
# Processing Frame :  31
# Processing Frame :  32
# Processing Frame :  33
# Processing Frame :  34
# Processing Frame :  35
# Processing Frame :  36
# Processing Frame :  37
# Processing Frame :  38
# Processing Frame :  39
# Processing Frame :  40
# ...

# %%
#==============Video detection scenario (camera)=============#
from imageai.Detection import VideoObjectDetection
import os
import cv2

execution_path = os.getcwd()

camera = cv2.VideoCapture(0)

detector = VideoObjectDetection()
detector.setModelTypeAsYOLOv3()
detector.setModelPath(os.path.join(execution_path , model_path3))
detector.loadModel()

video_path = detector.detectObjectsFromVideo(camera_input=camera,
    output_file_path=os.path.join(execution_path, "camera_detected_video")
    , frames_per_second=20, log_progress=True, minimum_percentage_probability=30)

print(video_path)
# Out:
# /content/camera_detected_video.avi

# %%
#==============Video detection scenario=============#
video_detector = VideoObjectDetection()
video_detector.setModelTypeAsYOLOv3()
video_detector.setModelPath(os.path.join(execution_path, model_path3))
video_detector.loadModel()



video_detector.detectObjectsFromVideo(input_file_path=os.path.join(execution_path, input_path4), output_file_path=os.path.join(execution_path, "video_analysis"))

# %%
#==============Video detection scenario=============#
from imageai.Detection import VideoObjectDetection
import os

execution_path = os.getcwd()

detector = VideoObjectDetection()
detector.setModelTypeAsYOLOv3()
detector.setModelPath( os.path.join(execution_path , model_path3))
detector.loadModel()

video_path = detector.detectObjectsFromVideo(input_file_path=os.path.join(execution_path, input_path4),
                            output_file_path=os.path.join(execution_path, output_path4)
                            , frames_per_second=20, log_progress=True)
print(video_path)
print(output_path4)
# Out:
# Processing Frame :  1
# Processing Frame :  2
# Processing Frame :  3
# Processing Frame :  4
# Processing Frame :  5
# Processing Frame :  6
# Processing Frame :  7
# Processing Frame :  8
# Processing Frame :  9
# Processing Frame :  10
# Processing Frame :  11
# Processing Frame :  12
# Processing Frame :  13
# Processing Frame :  14
# Processing Frame :  15
# Processing Frame :  16
# Processing Frame :  17
# Processing Frame :  18
# Processing Frame :  19
# Processing Frame :  20
# Processing Frame :  21
# Processing Frame :  22
# Processing Frame :  23
# Processing Frame :  24
# Processing Frame :  25
# Processing Frame :  26
# Processing Frame :  27
# Processing Frame :  28
# Processing Frame :  29
# Processing Frame :  30
# Processing Frame :  31
# Processing Frame :  32
# Processing Frame :  33
# Processing Frame :  34
# Processing Frame :  35
# Processing Frame :  36
# Processing Frame :  37
# Processing Frame :  38
# Processing Frame :  39
# Processing Frame :  40
# ...
